# %%
import pandas as pd
df = pd.read_csv("data/carPrices/train.csv")

# %%
df.head()
# Out:
#          ID  Price  Levy Manufacturer    Model  Prod. year   Category  \
# 0  45654403  13328  1399        LEXUS   RX 450        2010       Jeep
# 1  44731507  16621  1018    CHEVROLET  Equinox        2011       Jeep
# 2  45774419   8467     -        HONDA      FIT        2006  Hatchback
# 3  45769185   3607   862         FORD   Escape        2011       Jeep
# 4  45809263  11726   446        HONDA      FIT        2014  Hatchback
#
#   Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0              Yes    Hybrid           3.5  186005 km        6.0
# 1               No    Petrol             3  192000 km        6.0
# 2               No    Petrol           1.3  200000 km        4.0
# 3              Yes    Hybrid           2.5  168966 km        4.0
# 4              Yes    Petrol           1.3   91901 km        4.0
#
#   Gear box type Drive wheels   Doors             Wheel   Color  Airbags
# 0     Automatic          4x4  04-May        Left wheel  Silver       12
# ...

# %%
df = df[(df['Cylinders'] >= 4) & (df['Cylinders'] <= 12)]

# %%
df['Prod. year'].unique()
# Out:
# array([2010, 2011, 2006, 2014, 2016, 2013, 2007, 1999, 1997, 2018, 2008,
#        2012, 2017, 2001, 1995, 2009, 2000, 2019, 2015, 2004, 1998, 1990,
#        2005, 2003, 1985, 1996, 2002, 1993, 1992, 1988, 1977, 1989, 1994,
#        2020, 1984, 1991, 1983, 1953, 1964, 1987, 1943, 1978, 1986, 1965,
#        1976, 1957, 1980, 1939, 1968, 1947, 1981, 1973])

# %%
df = df.drop(columns=['Levy', 'ID', 'Doors', 'Leather interior', 'Wheel', 'Airbags'])

# %%
color_map = {
    "Silver": "Silver",
    "Black": "Black",
    "White": "White",
    "Grey": "Gray",
    "Blue": "Blue",
    "Sky blue": "Blue",
    "Green": "Green",
    "Red": "Red",
    "Carnelian red": "Red",
    "Orange": "Orange",
    "Yellow": "Gold",
    "Brown": "Brown",
    "Golden": "Gold",
    "Beige": "Beige",
    "Purple": "Purple",
    "Pink": "Red",
}
df['Color'] = df['Color'].map(color_map)

# %%
df['Mileage'] = df['Mileage'].str.replace('km', '', regex=False)

# %%
df['Mileage'] = df['Mileage'].astype(float)

# %%
df = df[(df['Mileage'] >= 0) & (df['Mileage'] <= 400000)]

# %%
df['Mileage'] = df['Mileage'].astype(float)

# %%
df['Cylinders'] = df['Cylinders'].astype(float)

# %%
BODY_TYPE_MAP = {
    "Jeep": "SUV",
    "Hatchback": "Hatchback",
    "Sedan": "Sedan",
    "Microbus": "Van",
    "Goods wagon": "Van",
    "Universal": "Wagon",
    "Coupe": "Coupe",
    "Minivan": "Van",
    "Cabriolet": "Convertible",
    "Limousine": "Sedan",
    "Pickup": "Pickup",
}
df['Category'] = df['Category'].map(BODY_TYPE_MAP)

# %%
GEARBOX_TYPE_MAP = {
    "Automatic": "Automatic",
    "Tiptronic": "Automatic",
    "Variator": "Automatic",  # CVT
    "Manual": "Manual",
}

# %%
df['Gear box type'] = df['Gear box type'].map(GEARBOX_TYPE_MAP)

# %%
df['Gear box type'] = df['Gear box type'].map({'Manual': 1, 'Automatic': 0})

# %%
drive_wheels_map = {
    '4x4': 'AWD',
    'Front': 'FWD',
    'Rear': 'RWD'}
df['Drive wheels'] = df['Drive wheels'].map(drive_wheels_map)

# %%
fuel_type_map = {
    "Hybrid": "Hybrid",
    "Plug-in Hybrid": "Hybrid",
    "Petrol": "Petrol",
    "Diesel": "Diesel",
    "CNG": "Petrol",
    "LPG": "Petrol",
    "Hydrogen": "Electric",
}
df['Fuel type'] = df['Fuel type'].map(fuel_type_map)

# %%
supported_makes = [
    "Toyota",
    "Hyundai",
    "Nissan",
    "Kia",
    "Honda",
    "Lexus",
    "GMC",
    "Chevrolet",
    "Ford",
    "Tesla",
    "BMW",
    "Mercedes-Benz",
    "Mitsubishi",
    "Land Rover",
    "Jeep",
    "Dodge",
    "Ram",
    "Volkswagen",
    "Audi",
    "Mazda",
    "Infiniti",
    "Cadillac",
    "Subaru",
]
supported_lookup = {make.lower(): make for make in supported_makes}

df["Manufacturer"] = df["Manufacturer"].astype(str).str.strip()
df = df[
    df["Manufacturer"].str.lower().isin(supported_lookup)
]

# %%
supported_models = [
    "Camry", "Corolla", "RAV4", "Highlander", "4Runner", "Tacoma", "Tundra", "Prius", "Sienna", "Sequoia", "Land Cruiser", "Crown",
    "Elantra", "Sonata", "Tucson", "Santa Fe", "Palisade", "Kona", "Venue", "Santa Cruz", "Ioniq 5", "Ioniq 6",
    "Altima", "Sentra", "Versa", "Rogue", "Murano", "Pathfinder", "Armada", "Frontier", "Leaf", "Kicks", "Z",
    "K4", "K5", "Forte", "Soul", "Seltos", "Sportage", "Sorento", "Telluride", "Carnival", "EV6", "EV9",
    "Accord", "Civic", "CR-V", "HR-V", "Pilot", "Odyssey", "Passport", "Ridgeline", "Prologue",
    "RX 350", "NX 350", "ES 350", "GX 550", "LX 600", "IS 350", "TX 350", "RC 350", "LS 500", "UX 300h",
    "Terrain", "Acadia", "Yukon", "Yukon XL", "Canyon", "Sierra 1500", "Sierra HD", "Hummer EV",
    "Trax", "Trailblazer", "Equinox", "Blazer", "Traverse", "Tahoe", "Suburban", "Colorado", "Silverado 1500", "Malibu", "Corvette",
    "Maverick", "Ranger", "F-150", "Mustang", "Escape", "Bronco Sport", "Bronco", "Explorer", "Expedition", "Transit",
    "Model 3", "Model Y", "Model S", "Model X", "Cybertruck",
    "2 Series", "3 Series", "4 Series", "5 Series", "7 Series", "X1", "X3", "X5", "X7", "i4", "iX",
    "C-Class", "E-Class", "S-Class", "GLA", "GLC", "GLE", "GLS", "EQB", "EQE", "G-Class",
    "Mirage", "Outlander", "Outlander Sport", "Eclipse Cross",
    "Range Rover", "Range Rover Sport", "Range Rover Velar", "Range Rover Evoque", "Discovery", "Defender",
    "Compass", "Cherokee", "Grand Cherokee", "Wrangler", "Gladiator", "Wagoneer", "Grand Wagoneer",
    "Hornet", "Durango", "Charger", "Challenger",
    "1500", "2500", "3500", "ProMaster",
    "Jetta", "Taos", "Tiguan", "Atlas", "Atlas Cross Sport", "Golf GTI", "Golf R", "ID.4",
    "A3", "A4", "A5", "A6", "Q3", "Q5", "Q7", "Q8", "e-tron", "Q4 e-tron",
    "Mazda3", "CX-30", "CX-5", "CX-50", "CX-70", "CX-90", "MX-5 Miata",
    "Q50", "QX50", "QX55", "QX60", "QX80",
    "CT4", "CT5", "XT4", "XT5", "XT6", "Escalade", "Lyriq", "Optiq",
    "Impreza", "Legacy", "WRX", "Crosstrek", "Forester", "Outback", "Ascent", "BRZ", "Solterra",
]
# supported_models = [model.upper() for model in supported_models]
supported_lookup = {model.lower(): model for model in supported_models}

df["Model"] = df["Model"].astype(str).str.strip()
df = df[
    df["Model"].str.lower().isin(supported_lookup)
]

# %%
df['car_age'] = 2026 - df['Prod. year']

# %%
df = pd.get_dummies(df, columns=['Manufacturer', 'Color', 'Category', 'Fuel type', 'Drive wheels'], drop_first=False)

# %%
df['Price'] = df['Price'].astype(float)
df['Prod. year'] = df['Prod. year'].astype(float)
df['Gear box type'] = df['Gear box type'].astype(float)
df['car_age'] = df['car_age'].astype(float)

# %%
df['Engine volume'] = df['Engine volume'].map(df['Engine volume'].value_counts()).astype(float)

# %%
df = df[(df['Price'] >= 500) & (df['Price'] < 150000)]

# %%
from sklearn.model_selection import train_test_split
import numpy as np
# X = df.drop(columns=['Price'])
# y = df['Price']
train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)

model_

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, r2_score

model = RandomForestRegressor()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

print("MAE:", mean_absolute_error(y_test, y_pred))
print("R2:", r2_score(y_test, y_pred))
# Out:
# MAE: 4754.959761687727
# R2: 0.7392110087374038
